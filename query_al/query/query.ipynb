# %% [markdown]
# ### 데이터 불러오기

# %%
from PIL import ImageGrab
from collections import Counter
import pandas as pd
import numpy as np
import win32gui
import pytesseract
import cv2
import face_recognition
import time
import subprocess as sb

# 질문 db 불러오기
who_df = pd.read_csv("./dataset/query_who.csv", encoding='cp949')
place_df = pd.read_csv("./dataset/query_place.csv") 
when_df = pd.read_csv("./dataset/query_when.csv") 
what_df = pd.read_csv("./dataset/query_what.csv") 
where_df = pd.read_csv("./dataset/query_where.csv") 
entity_df = pd.read_csv("./dataset/entity_dataset.csv", encoding='cp949')

# %%
# entity 항목 불러오기
entity_who = entity_df.loc[0, 'entity'].split(', ')
entity_place = entity_df.loc[1, 'entity'].split(', ')
entity_time = entity_df.loc[2, 'entity'].split(', ')
entity_object = entity_df.loc[3, 'entity'].split(', ')
entity_body = entity_df.loc[4, 'entity'].split(', ')

# %%
# 언제에 해당하는 entity에 시간 추가
for i in range(1, 13):
    tmp = str(i) + '시'
    entity_time.append(tmp)

# %% [markdown]
# ## 본문

# %% [markdown]
# #### 재입력 기능

# %%
# 장애인이 틀렸다고 한 부분만 다시 입력하는 기능
# 입력한 내용인 db에 있는지 확인
# ex) 장애인이 때린 사람을 아저씨, 활동보조인으로 입력
# db에 '아저씨', '활동보조인'이 없을 경우 재입력 요구
def __anschk__(ans, df):

    if ans in df:
        return True

    return False

# %% [markdown]
# ### 전체 함수

# %%
expected_A1 = {'네', '아니요', '잘 모르겠어요'}
expected_A2 = {'누가', '어디서', '언제', '무엇으로', '어디를'}

def YNanswer(screen):
    ansok = False
    while not ansok:

        time.sleep(3)
        bbox = win32gui.GetWindowRect(screen)
        img = ImageGrab.grab(bbox)
        area = (10, 270, 130, 315)
        cr_img = img.crop(area)
        ans = pytesseract.image_to_string(cr_img, lang='kor', config='-c preserve_interword_spaces=1 --psm 4')
        ans = ans.strip()
        if ans in expected_A1 or '잘 모르겠' in ans:
            ansok = True
        elif ans in expected_A2:
            ansok = True
            
    return ans

# %%
def SPanswer(screen):
    ansok = False
    while not ansok:

        time.sleep(3)
        bbox = win32gui.GetWindowRect(screen)
        img = ImageGrab.grab(bbox)
        area = (10, 270, 130, 315)
        cr_img = img.crop(area)
        ans = pytesseract.image_to_string(cr_img, lang='kor', config='-c preserve_interword_spaces=1 --oem 3 --psm 7')
        ans = ans.strip()
        if ans == '0':
            continue
        elif '잘 모르겠' in ans:
            ansok = True
        else:
            ansok = True
            
    return ans

# %% [markdown]
# #### 누가

# %%
# 누가
def __who__(screen):
    
    no_ans = '모르는 사람' 
    temp = who_df.query('label == [0]').sample(n=5) # csv에서 랜덤으로 라벨이 0인 질문 5개 추출
    temp = temp.loc[:, 'Q'].tolist() # 뽑은 질문을 리스트로 변환
    pass_cnt = 0 # 아니오를 2번 이상 답할 경우 대상을 모르는 것으로 알고 다음 질문을 넘어감
                 # 예를 들어 누가 때렸는지 알아요? 라는 질문에 2번 아니오라 답하면 때린 인물이 기억이 안나는 것으로 보고 '어디서' 질문으로 넘어감
    step_pass = False
                 # 다음 label 질문으로 넘어가도 되는지 확인하는 bool

    for q in temp:
        if step_pass:
            break
        print(q)
        q_pass = False
        # label은 그대로하고 질문만 새롭게 출력하는 것을 확인하는 bool
        while not q_pass:
            ans = YNanswer(screen)
            if ans == '네':
                q_pass = True
                step_pass = True
                print(ans)
            elif ans == '아니요':
                print(ans)
                pass_cnt += 1
                if pass_cnt == 2:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans
                elif q == temp[-1]:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')   
                    return no_ans                 
                print('장애인 분을 위해서 때린 사람이 누구인지 확실하게 알 필요가 있어요.\
                    \n질문이 이해가 안 가시면 잘 모르겠다고 답해주세요.\
                    \n기억이 나지 않는다면 한 번 더 아니오를 눌러주세요.\
                    \n아니오를 한 번 더 누르면 다음 질문을 할게요.')
                print('질문을 다르게 해볼게요.')
                q_pass = True
            elif '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == temp[-1] and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans
                print('질문을 다르게 해볼게요.')
                q_pass = True

    temp = who_df.query('label == [1]').sample(n=5) # 라벨이 1인 질문 중 5개를 랜덤으로 추출
    temp = temp.loc[:, 'Q'].tolist()
    step_pass = False

    for q in temp:
        if step_pass:
            break
        print(q)
        q_pass = False
        while not q_pass:
            ans = SPanswer(screen)

            if '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == temp[-1] and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    
                    return no_ans
                print('질문을 다르게 해볼게요.')
                q_pass = True
                
            else:
                print(ans)
                ans_pass = __anschk__(ans, entity_who)
                if ans_pass:
                    whotmp = ans
                    q_pass = True
                    step_pass = True
                elif not ans_pass:
                    print("'인물' 항목에서 답변해주세요.")
                    print('질문을 다시 할게요.')
                    q_pass = True

    print('때린 사람이 '+whotmp+'(이)였군요.')  

    return whotmp

# %% [markdown]
# #### 어디서

# %%
# 어디서
def __place__(who, screen):

    no_ans = '모르는 장소'
    placelist = place_df.query('label == [0]').sample(n=5)
    placelist = placelist.loc[:, 'Q'].tolist()
    pass_cnt = 0

    step_pass = False
    
    for q in placelist:
        if step_pass:
            break
        q = q.replace('{tag_people}', who)
        q_last = placelist[-1].replace('{tag_people}', who)
        print(q)
        q_pass = False

        while not q_pass:
            ans = YNanswer(screen)
            if ans == '네':
                q_pass = True
                step_pass = True
                print(ans)
            elif ans == '아니요':
                print(ans)
                pass_cnt += 1
                if pass_cnt == 2:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans
                elif q == placelist[-1]:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')   
                    return no_ans                    
                print('장애인 분을 위해서 '+who+'(이)가 어디서 때렸는지 확실하게 알 필요가 있어요.\
                    \n질문이 이해가 안 가시면 잘 모르겠다고 답해주세요.\
                    \n기억이 나지 않는다면 한 번 더 아니오를 눌러주세요.\
                    \n아니오를 한 번 더 누르면 다음 질문을 할게요.')
                print('질문을 다르게 해볼게요.')
                q_pass = True
            elif '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == q_last and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans               
                print('질문을 다르게 해볼게요.')
                q_pass = True

    placelist = place_df.query('label == [1]').sample(n=5)
    placelist = placelist.loc[:, 'Q'].tolist()
    step_pass = False

    for q in placelist:
        if step_pass:
            break
        q_pass = False
        q = q.replace('{tag_people}', who)
        print(q)
        step_pass = False
        while not q_pass:
            ans = SPanswer(screen)
            if '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == q_last and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans
                print('질문을 다르게 해볼게요.')
                q_pass = True
                
            else:
                print(ans)
                ans_pass = __anschk__(ans, entity_place)
                if ans_pass:
                    wheretmp = ans
                    q_pass = True
                    step_pass = True
                elif not ans_pass:
                    print("'인물' 항목에서 답변해주세요.")
                    print('질문을 다시 할게요.')
                    q_pass = True
                
    print(who+'(이)가 때린 장소가 '+wheretmp+'(이)였군요.')          
    
    return wheretmp

# %% [markdown]
# #### 언제

# %%
def __when__(who, place, screen):

    no_ans = '모르는 시간'
    whenlist = when_df.query('label == [0]').sample(n=5)
    whenlist = whenlist.loc[:, 'Q'].tolist()

    step_pass = False
    pass_cnt = 0

    for q in whenlist:
        if step_pass:
            break
        q = q.replace('{tag_people}', who).replace('{tag_place}', place)
        q_last = whenlist[-1].replace('{tag_people}', who).replace('{tag_place}', place)
        print(q)
        q_pass = False
        while not q_pass:
            ans = YNanswer(screen)
            if ans == '네':
                q_pass = True
                step_pass = True
                print(ans)
            elif ans == '아니요':
                print(ans)
                pass_cnt += 1
                if pass_cnt == 2:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans
                elif q == whenlist[-1]:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')   
                    return no_ans                   
                print('장애인 분을 위해서'+who+'(이)가 언제 때렸는지 확실하게 알 필요가 있어요.\
                    \n질문이 이해가 안 가시면 잘 모르겠다고 답해주세요.\
                    \n기억이 나지 않는다면 한 번 더 아니오를 눌러주세요.\
                    \n아니오를 한 번 더 누르면 다음 질문을 할게요.')
                print('질문을 다르게 해볼게요.')
                q_pass = True
            elif '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == q_last and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans

                print('질문을 다르게 해볼게요.')
                q_pass = True

    whenlist = when_df.query('label == [1]').sample(n=5)
    whenlist = whenlist.loc[:, 'Q'].tolist()
    
    step_pass = False

    for q in whenlist:
        if step_pass:
            break
        q_pass = False
        q = q.replace('{tag_people}', who).replace('{tag_place}', place)
        print(q)
        step_pass = False
        while not q_pass:
            ans = SPanswer(screen)

            if '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == q_last and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    
                    return no_ans
                print('질문을 다르게 해볼게요.')
                q_pass = True
                
            else:
                print(ans)
                ans_pass = __anschk__(ans, entity_time)
                if ans_pass:
                    whentmp = ans
                    q_pass = True
                    step_pass = True
                elif not ans_pass:
                    print("'시간' 항목에서 답변해주세요.")
                    print('질문을 다시 할게요.')
                    q_pass = True

    print(who+'(이)가 '+place+'에서 장애인님을 때렸군요. 때린 시간은 '+whentmp+'(이)였구요.')

    return whentmp

# %% [markdown]
# #### 무엇으로

# %%
def __what__(who, place, when, screen):

    no_ans = '모르는 물건'
    temp = what_df.query('label == [0]').sample(n=5)
    temp = temp.loc[:, 'Q'].tolist()
    step_pass = False

    for q in temp:
        if step_pass:
            break
        q = q.replace('{tag_people}', who).replace('{tag_place}', place).replace('{tag_time}', when)
        q_last = temp[-1].replace('{tag_people}', who).replace('{tag_place}', place).replace('{tag_time}', when)
        print(q)
        q_pass = False
        while not q_pass:
            ans = YNanswer(screen)
            if ans == '네':
                q_pass = True
                step_pass = True
                print(ans)
            elif ans == '아니요':
                print('장애인님을 때릴 때 도구를 사용하지 않았군요.')
                return '맨손'
                
            elif '잘 모르겠' in ans:
                if q == q_last and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans
                print('잘 모르겠어요')
                print('질문을 다르게 해볼게요.')
                q_pass = True

    temp = what_df.query('label == [1]').sample(n=5)
    temp = temp.loc[:, 'Q'].tolist()
    step_pass = False

    for q in temp:
        if step_pass:
            break
        q_pass = False
        q = q.replace('{tag_people}', who).replace('{tag_place}', place).replace('{tag_time}', when)
        print(q)
        step_pass = False
        while not q_pass:
            ans = SPanswer(screen)
            
            if '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == q_last and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')

                    return no_ans
                print('질문을 다르게 해볼게요.')
                q_pass = True
                
            else:
                print(ans)
                ans_pass = __anschk__(ans, entity_object)
                if ans_pass:
                    whattmp = ans
                    q_pass = True
                    step_pass = True
                elif not ans_pass:
                    print("'장소' 항목에서 답변해주세요.")
                    print('질문을 다시 할게요.')
                    q_pass = True
                    
    print(who+'(이)가 '+place+'에서 '+whattmp+'로 장애인님을 때렸군요. 때린 시간은 '+when+'(이)였구요.')
      
    return whattmp

# %% [markdown]
# #### 어디를

# %%
def __where__(who, place, when, what, screen):

    no_ans = '모르는 부위'
    temp = where_df.query('label == [0]').sample(n=5)
    temp = temp.loc[:, 'Q'].tolist()
    step_pass = False
    pass_cnt = 0
    
    for q in temp:
        if step_pass:
            break
        q = q.replace('{tag_people}', who).replace('{tag_place}', place).replace('{tag_time}', when).replace('{tag_object}', what)
        q_last = temp[-1].replace('{tag_people}', who).replace('{tag_place}', place).replace('{tag_time}', when).replace('{tag_object}', what)
        print(q)
        q_pass = False
        while not q_pass:
            ans = YNanswer(screen)
            if ans == '네':
                q_pass = True
                step_pass = True
                print(ans)
            elif ans == '아니요':
                print(ans)
                pass_cnt += 1
                if pass_cnt == 2:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans
                elif q == temp[-1]:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')   
                    return no_ans 
                print('저희가 장애인 분을 확실히 도와드리고 싶어요.\
                    \n도와드리기 위해서는 ',who,'(이)가 어디를 때렸는지 알아야해요.\
                    \n기억이 나지 않거나 질문이 이해가 안 가시면 잘 모르겠다고 답해주세요')
                print('질문을 다시 할게요.')
                q_pass = True
            elif '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == q_last and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')
                    return no_ans

                print('질문을 다르게 해볼게요.')
                q_pass = True

    temp = where_df.query('label == [1]').sample(n=5)
    temp = temp.loc[:, 'Q'].tolist()
    step_pass = False

    for q in temp:
        if step_pass:
            break
        q_pass = False
        q = q.replace('{tag_people}', who).replace('{tag_place}', place).replace('{tag_time}', when).replace('{tag_object}', what)
        print(q)
        step_pass = False
        while not q_pass:
            ans = SPanswer(screen)
    
            if '잘 모르겠' in ans:
                print('잘 모르겠어요')
                if q == q_last and step_pass == False:
                    print('기억이 나지 않나 보네요.\n괜찮습니다. 나중에라도 기억이 나면 알려주세요.')

                    return no_ans
                print('질문을 다르게 해볼게요.')
                q_pass = True  
                  
            else:
                print(ans)
                ans_pass = __anschk__(ans, entity_body)
                if ans_pass:
                    wheretmp = ans
                    q_pass = True
                    step_pass = True
                elif not ans_pass:
                    print("'몸' 항목에서 답변해주세요.")
                    print('질문을 다시 할게요.')
                    q_pass = True
                    
    print(who+'(이)가 '+what+'(으)로 '+wheretmp+'를 때렸군요.')

    return wheretmp

# %% [markdown]
# #### 재입력 기능

# %%
def __check__(who, place, when, what, where, screen):
    chksen = who+'(이)가 '+place+'에서 '+when+', '+what+'으로 장애인님의 '+where+'(을)를 때린게 맞나요?'
    print(chksen)
    step_pass = False
    while not step_pass:
        ans = YNanswer(screen)
        if ans == '네':
            print(ans)
            print('신고가 정상적으로 접수되었습니다. 금방 연락을 드릴게요.')
            step_pass = True
            return who, place, when, what, where, True
        elif ans == '아니요':
            print(ans)
            print('어디가 틀린건지 얘기해주세요.')
            wrong = YNanswer(screen)
            if wrong == '누가':
                who = __who__()
            elif wrong == '어디서':
                place = __place__(who, screen)
            elif wrong == '언제':
                when = __when__(who, place, screen)
            elif wrong == '무엇으로':
                what = __what__(who, place, when, screen)
            elif wrong == '어디를':
                where = __where__(who, place, when, what, screen)
            
            return who, place, when, what, where, False

# %% [markdown]
# ### 얼굴 인식

# %%
video_capture = cv2.VideoCapture(0)

# 얼굴 학습
Ko_image = face_recognition.load_image_file("./test_c/KakaoTalk_20221127_184457705.jpg")
Ko_face_encoding = face_recognition.face_encodings(Ko_image)[0]

Kwon_image = face_recognition.load_image_file("./test_c/KakaoTalk_20221129_205044499.jpg")
Kwon_face_encoding = face_recognition.face_encodings(Kwon_image)[0]

Jang_image = face_recognition.load_image_file("./test_c/KakaoTalk_20221129_204921270.jpg")
Jang_face_encoding = face_recognition.face_encodings(Jang_image)[0]

Baek_image = face_recognition.load_image_file("./test_c/KakaoTalk_20221129_204941840.jpg")
Baek_face_encoding = face_recognition.face_encodings(Baek_image)[0]

known_face_encodings = [
    Ko_face_encoding,
    Kwon_face_encoding,
    Jang_face_encoding,
    Baek_face_encoding
]
known_face_names = [
    "ID: 2015111766",
    "ID: 2019113394",
    "Jang Jiwook",
    "Baek Jongrok"
]

face_locations = []
face_encodings = []
face_names = []
process_this_frame = True
cnt = 0
chk_list = []

while True:

    ret, frame = video_capture.read()

    if process_this_frame:
        # 영상 설정
        small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

        rgb_small_frame = small_frame[:, :, ::-1]
    
        face_locations = face_recognition.face_locations(rgb_small_frame)
        face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_face_names[best_match_index]

            face_names.append(name)

    process_this_frame = not process_this_frame


    for (top, right, bottom, left), name in zip(face_locations, face_names):
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # 인식된 얼굴 주변을 박스로 표시
        cv2.rectangle(frame, (left, top), (right, bottom), (255, 0, 0), 2)

        # 얼굴에 표시
        # BGR 순으로 표시된다.
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (255, 191, 0), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 0.5, (255, 255, 255), 1)
        chk_list.append(name)

    # 결과창 표시
    cv2.imshow('Video', frame)
    
    # 일정 빈도 이상 인식되면 얼굴 확인 완료
    if chk_list:
        counter = Counter(chk_list)
        if counter.most_common()[0][1] == 15:
            T_name = name
            break
    

    # q를 눌러 종료
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
    if key == ord('p'):
        cv2.waitKey(-1) #wait until any key is pressed
    

# 사용하고 있던 웹캠 놓기
video_capture.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 실행

# %%
if T_name == 'ID: 2015111766':
    name = '바이오환경과학과 고상현'
elif T_name == 'ID: 2019113394':
    name = '일본학과 권석현'

print('안녕하세요. '+name+'님')
sb.Popen('../myAAC_pc.app/나의AAC PC (Ver 2.0).exe')
time.sleep(3)
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\sangh\AppData\Local\Tesseract-OCR\tesseract.exe'
screen = win32gui.FindWindow(None, '나의AAC PC (ver 2.0)')
if screen != 0:
    print('aac가 실행중입니다.')

print('질문을 시작하겠습니다.\n최대한 모두 대답해주세요')

print('-----------------------------------누가---------------------------------------')
tag_who = __who__(screen)
print('이제부터 '+tag_who+'(이)가 어디서 때렸는지 물어볼게요')
print('-----------------------------------어디서---------------------------------------')
tag_place = __place__(tag_who, screen)
print('이제부터 '+tag_who+'(이)가 언제 때렸는지 물어볼게요')
print('-----------------------------------언제---------------------------------------')
tag_when = __when__(tag_who, tag_place, screen)
print('이제부터 '+tag_who+'(이)가 무엇으로 때렸는지 물어볼게요')
print('-----------------------------------무엇으로---------------------------------------')
tag_what = __what__(tag_who, tag_place, tag_when, screen)
print('이제부터 '+tag_who+'(이)가 '+tag_what+'(으)로 어디를 때렸는지 물어볼게요')
print('-----------------------------------어디를---------------------------------------')
tag_where = __where__(tag_who, tag_place, tag_when, tag_what, screen)
print('-----------------------------------질문 종료---------------------------------------')
print('\n질문은 이걸로 끝입니다.\n대답해주신걸 다시 확인해볼게요.')

ok = False
while not ok:
    tag_who, tag_place, tag_when, tag_what, tag_where, ok = __check__(tag_who, tag_place, tag_when, tag_what, tag_where, screen)
    if not ok:
        print('다시 확인할게요.')
# Out:
# 안녕하세요. 바이오환경과학과 고상현님
# aac가 실행중입니다.
# 질문을 시작하겠습니다.
# 최대한 모두 대답해주세요
# -----------------------------------누가---------------------------------------
# 폭행한 사람이 누구인지 알고 있나요?
# 아니요
# 장애인 분을 위해서 때린 사람이 누구인지 확실하게 알 필요가 있어요.
# 질문이 이해가 안 가시면 잘 모르겠다고 답해주세요.
# 기억이 나지 않는다면 한 번 더 아니오를 눌러주세요.
# 아니오를 한 번 더 누르면 다음 질문을 할게요.
# 질문을 다르게 해볼게요.
# 당신을 폭행한 사람이 누구인지 기억나요?
# 아니요
# 기억이 나지 않나 보네요.
# 괜찮습니다. 나중에라도 기억이 나면 알려주세요.
# 이제부터 모르는 사람(이)가 어디서 때렸는지 물어볼게요
# -----------------------------------어디서---------------------------------------
# 모르는 사람(이)가 장애인님을 폭행한 장소가 기억나세요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 어디서 장애인님이 폭행을 당했는지 알려주실 수 있나요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 장애인님을 모르는 사람(이)가 때린 장소가 어딘지 기억나세요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 어디서 모르는 사람가 때렸는지 기억나세요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 모르는 사람(이)가 폭행한 장소가 기억나요?
# 잘 모르겠어요
# 기억이 나지 않나 보네요.
# 괜찮습니다. 나중에라도 기억이 나면 알려주세요.
# 이제부터 모르는 사람(이)가 언제 때렸는지 물어볼게요
# -----------------------------------언제---------------------------------------
# 모르는 사람(이)가 장애인님을 때린 시간이 기억나요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 정확히 언제 모르는 사람(이)가 때렸는지 기억나요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 장애인님이 모르는 장소에서 언제 폭행을 당한건지 기억나나요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 장애인님이 모르는 장소에서 폭행을 당한 시간이 기억나요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 모르는 장소에서 장애인님이 모르는 사람한테 폭행을 다한 시간이 기억나나요?
# 잘 모르겠어요
# 기억이 나지 않나 보네요.
# 괜찮습니다. 나중에라도 기억이 나면 알려주세요.
# 이제부터 모르는 사람(이)가 무엇으로 때렸는지 물어볼게요
# -----------------------------------무엇으로---------------------------------------
# 모르는 사람(이)가 장애인님을 때릴 때 사용한 물건이 있나요?
# 잘 모르겠어요
# 질문을 다르게 해볼게요.
# 모르는 장소에서 모르는 사람(이)가 당신을 때릴 때 사용한 도구가 있었나요?
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\sangh\Desktop\2022-2-SCS4031-4MEN-personal\query\query.ipynb 셀 26 in <cell line: 26>()
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=23'>24</a> print('이제부터 '+tag_who+'(이)가 무엇으로 때렸는지 물어볼게요')
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=24'>25</a> print('-----------------------------------무엇으로---------------------------------------')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=25'>26</a> tag_what = __what__(tag_who, tag_place, tag_when, screen)
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=26'>27</a> print('이제부터 '+tag_who+'(이)가 '+tag_what+'(으)로 어디를 때렸는지 물어볼게요')
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=27'>28</a> print('-----------------------------------어디를---------------------------------------')
#
# c:\Users\sangh\Desktop\2022-2-SCS4031-4MEN-personal\query\query.ipynb 셀 26 in __what__(who, place, when, screen)
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=13'>14</a> q_pass = False
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=14'>15</a> while not q_pass:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=15'>16</a>     ans = YNanswer(screen)
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=16'>17</a>     if ans == '네':
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=17'>18</a>         q_pass = True
#
# c:\Users\sangh\Desktop\2022-2-SCS4031-4MEN-personal\query\query.ipynb 셀 26 in YNanswer(screen)
#       <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> while not ansok:
#       <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=7'>8</a>     time.sleep(3)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=8'>9</a>     bbox = win32gui.GetWindowRect(screen)
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=9'>10</a>     img = ImageGrab.grab(bbox)
#      <a href='vscode-notebook-cell:/c%3A/Users/sangh/Desktop/2022-2-SCS4031-4MEN-personal/query/query.ipynb#X34sZmlsZQ%3D%3D?line=10'>11</a>     area = (10, 270, 130, 315)
#
# error: (1400, 'GetWindowRect', '잘못된 창 핸들입니다.')
